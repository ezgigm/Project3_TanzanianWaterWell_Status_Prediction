# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('clean_data.csv')

# %%
df
# Out:
#        Unnamed: 0  status_group           funder  gps_height     installer  \
# 0               0             0            Roman        1390         Roman
# 1               1             0          Grumeti        1399       GRUMETI
# 2               2             0     Lottery Club         686  world vision
# 3               3             1           Unicef         263        Unicef
# 4               4             0      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 59395       59395             0  Germany Republi        1210           CES
# 59396       59396             0      Cefa-njombe        1212          Cefa
# 59397       59397             0          Unknown           0       Unknown
# 59398       59398             0            Malec           0          Musa
# 59399       59399             0       World Bank         191         World
#
#        longitude   latitude                    basin       region  \
# ...

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#        status_group           funder  gps_height     installer  longitude  \
# 0                 0            Roman        1390         Roman  34.938093
# 1                 0          Grumeti        1399       GRUMETI  34.698766
# 2                 0     Lottery Club         686  world vision  37.460664
# 3                 1           Unicef         263        Unicef  38.486161
# 4                 0      Action In A           0       Artisan  31.130847
# ...             ...              ...         ...           ...        ...
# 59395             0  Germany Republi        1210           CES  37.169807
# 59396             0      Cefa-njombe        1212          Cefa  35.249991
# 59397             0          Unknown           0       Unknown  34.017087
# 59398             0            Malec           0          Musa  35.861315
# 59399             0       World Bank         191         World  38.104048
#
#         latitude                    basin       region  district_code  \
# ...

# %%
df1=pd.read_csv('cleaned.csv')

# %%
df1=df1.drop(columns='Unnamed: 0')

# %%
df1
# Out:
#           id    status_group  amount_tsh date_recorded           funder  \
# 0      69572      functional      6000.0    2011-03-14            Roman
# 1       8776      functional         0.0    2013-03-06          Grumeti
# 2      34310      functional        25.0    2013-02-25     Lottery Club
# 3      67743  non functional         0.0    2013-01-28           Unicef
# 4      19728      functional         0.0    2011-07-13      Action In A
# ...      ...             ...         ...           ...              ...
# 59395  60739      functional        10.0    2013-05-03  Germany Republi
# 59396  27263      functional      4700.0    2011-05-07      Cefa-njombe
# 59397  37057      functional         0.0    2011-04-11          Unknown
# 59398  31282      functional         0.0    2011-03-08            Malec
# 59399  26348      functional         0.0    2011-03-23       World Bank
#
#        gps_height     installer  longitude   latitude              wpt_name  \
# ...

# %%
df.funder_cat.nunique()
# Out:
# 21

# %%
df.installer_cat.nunique()
# Out:
# 17

# %%
df['status_code']= np.where(df1["status_group"]=="non functional", 0, 1)
df['status_code']
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 59395    1
# 59396    1
# 59397    1
# 59398    1
# 59399    1
# Name: status_code, Length: 59400, dtype: int32

# %%
df
# Out:
#        status_group           funder  gps_height     installer  longitude  \
# 0                 0            Roman        1390         Roman  34.938093
# 1                 0          Grumeti        1399       GRUMETI  34.698766
# 2                 0     Lottery Club         686  world vision  37.460664
# 3                 1           Unicef         263        Unicef  38.486161
# 4                 0      Action In A           0       Artisan  31.130847
# ...             ...              ...         ...           ...        ...
# 59395             0  Germany Republi        1210           CES  37.169807
# 59396             0      Cefa-njombe        1212          Cefa  35.249991
# 59397             0          Unknown           0       Unknown  34.017087
# 59398             0            Malec           0          Musa  35.861315
# 59399             0       World Bank         191         World  38.104048
#
#         latitude                    basin       region  district_code  \
# ...

# %%
df['status_group']=df1.status_group
df
# Out:
#          status_group           funder  gps_height     installer  longitude  \
# 0          functional            Roman        1390         Roman  34.938093
# 1          functional          Grumeti        1399       GRUMETI  34.698766
# 2          functional     Lottery Club         686  world vision  37.460664
# 3      non functional           Unicef         263        Unicef  38.486161
# 4          functional      Action In A           0       Artisan  31.130847
# ...               ...              ...         ...           ...        ...
# 59395      functional  Germany Republi        1210           CES  37.169807
# 59396      functional      Cefa-njombe        1212          Cefa  35.249991
# 59397      functional          Unknown           0       Unknown  34.017087
# 59398      functional            Malec           0          Musa  35.861315
# 59399      functional       World Bank         191         World  38.104048
#
# ...

# %%
df["payment_value"] = np.where(df["payment"]=="never pay", 0, 1)
df
# Out:
#          status_group           funder  gps_height     installer  longitude  \
# 0          functional            Roman        1390         Roman  34.938093
# 1          functional          Grumeti        1399       GRUMETI  34.698766
# 2          functional     Lottery Club         686  world vision  37.460664
# 3      non functional           Unicef         263        Unicef  38.486161
# 4          functional      Action In A           0       Artisan  31.130847
# ...               ...              ...         ...           ...        ...
# 59395      functional  Germany Republi        1210           CES  37.169807
# 59396      functional      Cefa-njombe        1212          Cefa  35.249991
# 59397      functional          Unknown           0       Unknown  34.017087
# 59398      functional            Malec           0          Musa  35.861315
# 59399      functional       World Bank         191         World  38.104048
#
# ...

# %%
df.district_code.value_counts()
# Out:
# 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
df1.region_code.value_counts()
# Out:
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64

# %%
df['region_code']=df1.region_code
df
# Out:
#          status_group           funder  gps_height     installer  longitude  \
# 0          functional            Roman        1390         Roman  34.938093
# 1          functional          Grumeti        1399       GRUMETI  34.698766
# 2          functional     Lottery Club         686  world vision  37.460664
# 3      non functional           Unicef         263        Unicef  38.486161
# 4          functional      Action In A           0       Artisan  31.130847
# ...               ...              ...         ...           ...        ...
# 59395      functional  Germany Republi        1210           CES  37.169807
# 59396      functional      Cefa-njombe        1212          Cefa  35.249991
# 59397      functional          Unknown           0       Unknown  34.017087
# 59398      functional            Malec           0          Musa  35.861315
# 59399      functional       World Bank         191         World  38.104048
#
# ...

# %%
df.nunique()
# Out:
# status_group                 3
# funder                    1896
# gps_height                2428
# installer                 2053
# longitude                57516
# latitude                 57517
# basin                        9
# region                      21
# district_code               20
# lga                        125
# ward                      2092
# population                1048
# public_meeting               2
# permit                       2
# construction_year           54
# extraction_type_group       13
# management                  12
# payment                      7
# water_quality                8
# quantity                     5
# source                      10
# waterpoint_type              7
# decade                       7
# installer_cat               17
# funder_cat                  21
# status_code                  2
# payment_value                2
# region_code                 27
# dtype: int64

# %%
df
# Out:
#          status_group           funder  gps_height     installer  longitude  \
# 0          functional            Roman        1390         Roman  34.938093
# 1          functional          Grumeti        1399       GRUMETI  34.698766
# 2          functional     Lottery Club         686  world vision  37.460664
# 3      non functional           Unicef         263        Unicef  38.486161
# 4          functional      Action In A           0       Artisan  31.130847
# ...               ...              ...         ...           ...        ...
# 59395      functional  Germany Republi        1210           CES  37.169807
# 59396      functional      Cefa-njombe        1212          Cefa  35.249991
# 59397      functional          Unknown           0       Unknown  34.017087
# 59398      functional            Malec           0          Musa  35.861315
# 59399      functional       World Bank         191         World  38.104048
#
# ...

# %%
df1
# Out:
#           id    status_group  amount_tsh date_recorded           funder  \
# 0      69572      functional      6000.0    2011-03-14            Roman
# 1       8776      functional         0.0    2013-03-06          Grumeti
# 2      34310      functional        25.0    2013-02-25     Lottery Club
# 3      67743  non functional         0.0    2013-01-28           Unicef
# 4      19728      functional         0.0    2011-07-13      Action In A
# ...      ...             ...         ...           ...              ...
# 59395  60739      functional        10.0    2013-05-03  Germany Republi
# 59396  27263      functional      4700.0    2011-05-07      Cefa-njombe
# 59397  37057      functional         0.0    2011-04-11          Unknown
# 59398  31282      functional         0.0    2011-03-08            Malec
# 59399  26348      functional         0.0    2011-03-23       World Bank
#
#        gps_height     installer  longitude   latitude              wpt_name  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['region_number']=lb.fit_transform(df['region'])
df[['region','region_number']]
# Out:
#             region  region_number
# 0           Iringa              3
# 1             Mara              9
# 2          Manyara              8
# 3           Mtwara             12
# 4           Kagera              4
# ...            ...            ...
# 59395  Kilimanjaro              6
# 59396       Iringa              3
# 59397        Mbeya             10
# 59398       Dodoma              2
# 59399     Morogoro             11
#
# [59400 rows x 2 columns]

# %%
df=df.drop(columns='region_code')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 28 columns):
# status_group             59400 non-null object
# funder                   59400 non-null object
# gps_height               59400 non-null int64
# installer                59400 non-null object
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# basin                    59400 non-null object
# region                   59400 non-null object
# district_code            59400 non-null int64
# lga                      59400 non-null object
# ward                     59400 non-null object
# population               59400 non-null int64
# public_meeting           59400 non-null bool
# permit                   59400 non-null bool
# construction_year        59400 non-null int64
# extraction_type_group    59400 non-null object
# management               59400 non-null object
# payment                  59400 non-null object
# ...

# %%
df.nunique()
# Out:
# status_group                 3
# funder                    1896
# gps_height                2428
# installer                 2053
# longitude                57516
# latitude                 57517
# basin                        9
# region                      21
# district_code               20
# lga                        125
# ward                      2092
# population                1048
# public_meeting               2
# permit                       2
# construction_year           54
# extraction_type_group       13
# management                  12
# payment                      7
# water_quality                8
# quantity                     5
# source                      10
# waterpoint_type              7
# decade                       7
# installer_cat               17
# funder_cat                  21
# status_code                  2
# payment_value                2
# region_number               21
# dtype: int64

# %%
df['funder_code']=lb.fit_transform(df["funder_cat"])
df[["funder", "funder_code"]]
# Out:
#                 funder  funder_code
# 0                Roman           11
# 1              Grumeti           11
# 2         Lottery Club           11
# 3               Unicef           16
# 4          Action In A           11
# ...                ...          ...
# 59395  Germany Republi            5
# 59396      Cefa-njombe           11
# 59397          Unknown           17
# 59398            Malec           11
# 59399       World Bank           19
#
# [59400 rows x 2 columns]

# %%
df['funder_code'].value_counts()
# Out:
# 11    26451
# 6      9084
# 17     4416
# 0      3114
# 7      2202
# 13     1374
# 19     1349
# 8      1287
# 20     1246
# 16     1057
# 14      877
# 2       843
# 1       829
# 12      826
# 4       811
# 10      765
# 5       610
# 15      602
# 9       590
# 18      583
# 3       484
# Name: funder_code, dtype: int64

# %%
df['installer_code']=lb.fit_transform(df["installer_cat"])
df[["installer_cat", "installer_code"]]
# Out:
#       installer_cat  installer_code
# 0            Others              10
# 1            Others              10
# 2      world vision              16
# 3            Others              10
# 4            Others              10
# ...             ...             ...
# 59395        Others              10
# 59396        Others              10
# 59397       Unknown              14
# 59398        Others              10
# 59399        Others              10
#
# [59400 rows x 2 columns]

# %%
df['basin_code']=lb.fit_transform(df["basin"])
df[["basin", "basin_code"]]
# Out:
#                          basin  basin_code
# 0                   Lake Nyasa           1
# 1                Lake Victoria           4
# 2                      Pangani           5
# 3      Ruvuma / Southern Coast           7
# 4                Lake Victoria           4
# ...                        ...         ...
# 59395                  Pangani           5
# 59396                   Rufiji           6
# 59397                   Rufiji           6
# 59398                   Rufiji           6
# 59399              Wami / Ruvu           8
#
# [59400 rows x 2 columns]

# %%
df.nunique()
# Out:
# status_group                 3
# funder                    1896
# gps_height                2428
# installer                 2053
# longitude                57516
# latitude                 57517
# basin                        9
# region                      21
# district_code               20
# lga                        125
# ward                      2092
# population                1048
# public_meeting               2
# permit                       2
# construction_year           54
# extraction_type_group       13
# management                  12
# payment                      7
# water_quality                8
# quantity                     5
# source                      10
# waterpoint_type              7
# decade                       7
# installer_cat               17
# funder_cat                  21
# status_code                  2
# payment_value                2
# region_number               21
# funder_code                 21
# installer_code              17
# ...

# %%
df['extraction_code']=lb.fit_transform(df["extraction_type_group"])
df[["extraction_type_group", "extraction_code"]]
# Out:
#       extraction_type_group  extraction_code
# 0                   gravity                1
# 1                   gravity                1
# 2                   gravity                1
# 3               submersible               10
# 4                   gravity                1
# ...                     ...              ...
# 59395               gravity                1
# 59396               gravity                1
# 59397                swn 80               11
# 59398           nira/tanira                5
# 59399           nira/tanira                5
#
# [59400 rows x 2 columns]

# %%
df['management_code']=lb.fit_transform(df["management"])
df[["management", "management_code"]]
# Out:
#         management  management_code
# 0              vwc                7
# 1              wug               11
# 2              vwc                7
# 3              vwc                7
# 4            other                1
# ...            ...              ...
# 59395  water board                9
# 59396          vwc                7
# 59397          vwc                7
# 59398          vwc                7
# 59399          vwc                7
#
# [59400 rows x 2 columns]

# %%
df['quality_code']=lb.fit_transform(df["water_quality"])
df[["water_quality", "quality_code"]]
# Out:
#       water_quality  quality_code
# 0              soft             6
# 1              soft             6
# 2              soft             6
# 3              soft             6
# 4              soft             6
# ...             ...           ...
# 59395          soft             6
# 59396          soft             6
# 59397      fluoride             1
# 59398          soft             6
# 59399         salty             4
#
# [59400 rows x 2 columns]

# %%
df['quantity_code']=lb.fit_transform(df["quantity"])
df[["quantity", "quantity_code"]]
# Out:
#            quantity  quantity_code
# 0            enough              1
# 1      insufficient              2
# 2            enough              1
# 3               dry              0
# 4          seasonal              3
# ...             ...            ...
# 59395        enough              1
# 59396        enough              1
# 59397        enough              1
# 59398  insufficient              2
# 59399        enough              1
#
# [59400 rows x 2 columns]

# %%
df['source_code']=lb.fit_transform(df["source"])
df[["source", "source_code"]]
# Out:
#                      source  source_code
# 0                    spring            8
# 1      rainwater harvesting            5
# 2                       dam            0
# 3               machine dbh            3
# 4      rainwater harvesting            5
# ...                     ...          ...
# 59395                spring            8
# 59396                 river            6
# 59397           machine dbh            3
# 59398          shallow well            7
# 59399          shallow well            7
#
# [59400 rows x 2 columns]

# %%
df['waterpoint_code']=lb.fit_transform(df["waterpoint_type"])
df[["waterpoint_type", "waterpoint_code"]]
# Out:
#                    waterpoint_type  waterpoint_code
# 0               communal standpipe                1
# 1               communal standpipe                1
# 2      communal standpipe multiple                2
# 3      communal standpipe multiple                2
# 4               communal standpipe                1
# ...                            ...              ...
# 59395           communal standpipe                1
# 59396           communal standpipe                1
# 59397                    hand pump                4
# 59398                    hand pump                4
# 59399                    hand pump                4
#
# [59400 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 37 columns):
# status_group             59400 non-null object
# funder                   59400 non-null object
# gps_height               59400 non-null int64
# installer                59400 non-null object
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# basin                    59400 non-null object
# region                   59400 non-null object
# district_code            59400 non-null int64
# lga                      59400 non-null object
# ward                     59400 non-null object
# population               59400 non-null int64
# public_meeting           59400 non-null bool
# permit                   59400 non-null bool
# construction_year        59400 non-null int64
# extraction_type_group    59400 non-null object
# management               59400 non-null object
# payment                  59400 non-null object
# ...

# %%
df_train=df.drop(columns=['status_group','funder','installer','basin','region','district_code','lga','ward',
                          'extraction_type_group','management','payment','water_quality','quantity','source',
                         'waterpoint_type','decade','installer_cat','funder_cat'])
df_train.head()
# Out:
#    gps_height  longitude   latitude  population  public_meeting  permit  \
# 0        1390  34.938093  -9.856322         109            True   False
# 1        1399  34.698766  -2.147466         280            True    True
# 2         686  37.460664  -3.821329         250            True    True
# 3         263  38.486161 -11.155298          58            True    True
# 4           0  31.130847  -1.825359         281            True    True
#
#    construction_year  status_code  payment_value  region_number  funder_code  \
# 0               1999            1              1              3           11
# 1               2010            1              0              9           11
# 2               2009            1              1              8           11
# 3               1986            0              0             12           16
# 4               2000            1              0              4           11
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 19 columns):
# gps_height           59400 non-null int64
# longitude            59400 non-null float64
# latitude             59400 non-null float64
# population           59400 non-null int64
# public_meeting       59400 non-null bool
# permit               59400 non-null bool
# construction_year    59400 non-null int64
# status_code          59400 non-null int32
# payment_value        59400 non-null int32
# region_number        59400 non-null int32
# funder_code          59400 non-null int32
# installer_code       59400 non-null int32
# basin_code           59400 non-null int32
# extraction_code      59400 non-null int32
# management_code      59400 non-null int32
# quality_code         59400 non-null int32
# quantity_code        59400 non-null int32
# source_code          59400 non-null int32
# waterpoint_code      59400 non-null int32
# ...

# %%
df_train.describe()
# Out:
#          gps_height     longitude      latitude    population  \
# count  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean     668.297239     35.149679 -5.706033e+00    281.055791
# std      693.116350      2.567349  2.946019e+00    451.765815
# min      -90.000000     29.607122 -1.164944e+01      1.000000
# 25%        0.000000     33.354079 -8.540621e+00    100.000000
# 50%      369.000000     35.150000 -5.021597e+00    281.000000
# 75%     1319.250000     37.178387 -3.326156e+00    281.000000
# max     2770.000000     40.345193 -2.000000e-08  30500.000000
#
#        construction_year   status_code  payment_value  region_number  \
# count       59400.000000  59400.000000   59400.000000   59400.000000
# mean         1997.925202      0.615758       0.573266       9.835606
# std            10.179591      0.486420       0.494607       5.936892
# min          1960.000000      0.000000       0.000000       0.000000
# ...

# %%
df_train.status_code.value_counts()
# Out:
# 1    36576
# 0    22824
# Name: status_code, dtype: int64

# %%
df_train.corr()
# Out:
#                    gps_height  longitude  latitude  population  \
# gps_height           1.000000  -0.021153 -0.035751   -0.032337
# longitude           -0.021153   1.000000 -0.280284   -0.078553
# latitude            -0.035751  -0.280284  1.000000    0.035497
# population          -0.032337  -0.078553  0.035497    1.000000
# public_meeting       0.037207   0.022080  0.009084   -0.002387
# permit               0.091959  -0.002248  0.070615   -0.060359
# construction_year   -0.102682  -0.043843  0.065456    0.030969
# status_code          0.106942  -0.026951  0.027984    0.014791
# payment_value        0.176738   0.036926 -0.110821   -0.014172
# region_number       -0.323833   0.013440 -0.025485    0.031226
# funder_code         -0.087352  -0.016710  0.032099    0.011725
# installer_code      -0.023499   0.063363 -0.028946    0.023766
# basin_code          -0.161768   0.530505 -0.218502   -0.019481
# extraction_code     -0.261342   0.145848 -0.000162    0.071910
# ...

# %%
df_train.to_csv('num_cols.csv')

# %%
df.to_csv('num_cat_cols.csv')
